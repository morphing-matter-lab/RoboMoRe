# %%
import time
from design import *
import importlib
import shutil
from utils import *
from openai import OpenAI
from prompts import *
import json
import numpy as np
from gymnasium.envs.robodesign.GPTAnt import GPTAntEnv

from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import os
import matplotlib.pyplot as plt

# %%
def load_logs_full(log_dir):
    # 找到 .tfevents 文件
    event_file = [f for f in os.listdir(log_dir) if f.startswith("events.out")][0]
    event_path = os.path.join(log_dir, event_file)

    # 加载日志
    event_acc = EventAccumulator(event_path)
    event_acc.Reload()

    # 获取所有 scalar tags
    all_tags = event_acc.Tags()["scalars"]

    # 筛选 reward 分量
    reward_tags = [tag for tag in all_tags if tag.startswith("reward/")]

    # 加载所有 reward 分量数据（完整）
    data_full = {}
    for tag in reward_tags:
        events = event_acc.Scalars(tag)
        values = [e.value for e in events]
        data_full[tag] = values

    # 加载 episode length（完整）
    ep_len_tag = "rollout/ep_len_mean"
    if ep_len_tag in all_tags:
        events = event_acc.Scalars(ep_len_tag)
        values = [e.value for e in events]
        data_full[ep_len_tag] = values

    return data_full

# %%
import prompts
class DGA:
    def __init__(self):
        # api_key = "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"
        api_key = "sk-Rw6My5mY4TfcjuDuJBbz0cdtAiUpkNsrbdSgAN1VR9cmSVoC"
        self.client = OpenAI(api_key=api_key, base_url = "http://chatapi.littlewheat.com/v1")
        # self.model = "gpt-3.5-turbo"
        self.model = "gpt-4-turbo"

    def extract_code(self, text):
        match = re.search(r'```python\n(.*?)\n```', text, re.DOTALL)
        return match.group(1).strip() if match else None

    def indent_code(self, code):
        return "\n".join(line if line.strip() else line for line in code.split("\n"))

    def generate_rewardfunc_eureka(self, rewardfunc_nums, best_message, iteration, folder_name):
        messages = [
            {"role": "system", "content": "You are a reinforcement learning reward function designer"},
            {"role": "user", "content": rewardfunc_prompts + best_message + zeroshot_rewardfunc_format}
        ]

        responses = self.client.chat.completions.create(
            model=self.model, messages=messages, n=rewardfunc_nums
        )
        
        files = []
        for i, choice in enumerate(responses.choices):
            reward_code = self.extract_code(choice.message.content)
            if reward_code:
                # full_code = self.indent_code(reward_code) + "\n"
                full_code = "import numpy as np \n" + self.indent_code(reward_code) + "\n"
                file_name =  f"GPTAnt_{i}_{iteration}.py"
                file_path = os.path.join(folder_name, "env", file_name)
                with open(file_path, "w") as fp:
                    fp.write(full_code)

                with open(file_path, "w") as fp:
                    fp.write(full_code)
                files.append(file_path)
                print(f"Saved: {file_path}")

        return files

# %%
folder_name = "results/eureka"
log_file = os.path.join(folder_name, "parameters.log")
logging.basicConfig(filename=log_file, level=logging.INFO, format="%(asctime)s - %(message)s")

# folder_name = setup_logging(div_flag=True)

best_fitness = float('-inf')  
best_morphology = None  
best_rewardfunc = None  
best_reward = None
best_material = None
best_efficiency = None

iterations = 5
morphology_nums = 1
rewardfunc_nums = 1

fitness_matrix = np.array([[None for _ in range(morphology_nums)] for _ in range(rewardfunc_nums)])
efficiency_matrix = np.array([[None for _ in range(morphology_nums)] for _ in range(rewardfunc_nums)])
fitness_list = []

# %%
morphology_list = [f'results/eureka/assets/GPTAnt_{i}.xml' for i in range(0,1) ]
parameter_list= [[0.25, 0.2, 0.2, 0.2, 0.2, 0.4, 0.4, 0.08, 0.08, 0.08]]
material_list = [compute_ant_volume(parameter) for parameter in parameter_list]
# Out:
# params: [0.25, 0.2, 0.2, 0.2, 0.2, 0.4, 0.4, 0.08, 0.08, 0.08]

# %%
eureka_rewardfunc_prompts = """We trained a RL policy using the provided function code and tracked
the values of the individual components in the reward function as well as global policy matrics such as fitness function and episode lengths after
10 epochs and the maximum, mean, and minimum values encountered:
{reward_reflection}

Please carefully analyze the policy feedback and provide a new, improved reward function that can better
solve the task. Some helpful tips for analyzing the policy feedback:

(1) If the fitness function rates are always zero or negative, then you must rewrite the entire reward function
(2) If the values for a certain reward component are near identiacal throughout, then this means RL is not able to optimize this component as it is written. You may 
consider 
    (a) Changing its scale or the value of its temperature parameter
    (b) Re-writing the reward component
    (c) Discarding the reward component
(3) If some reward components' magnitude is significanly larger, then you must rescale its value to a proper range
Please analyze each existing reward component in the suggested manner above first, and then write the reward function code
"""

# %%
designer = DGA()
best_message = ''

for iter in range(iterations):
    reward_reflection = ''
    rewardfunc_list = designer.generate_rewardfunc_eureka(rewardfunc_nums, best_message, iter, folder_name)
    logging.info(f"___________________coarse optimization iter{iter}_____________________")
    for i, rewardfunc in enumerate(rewardfunc_list):
        for j, morphology in enumerate(morphology_list):

            print(i, rewardfunc)
            print(j, morphology)

            shutil.copy(morphology, "GPTAnt.xml")
            shutil.copy(rewardfunc, "GPTrewardfunc.py")         

            import GPTrewardfunc
            importlib.reload(GPTrewardfunc)  # 重新加载模块
            from GPTrewardfunc import _get_rew
            GPTAntEnv._get_rew = _get_rew

            env_name = "GPTAntEnv"
            model_path = Train(j,  i, folder_name, total_timesteps=2e4, callback=True)
            fitness, reward = Eva(model_path)

            material = material_list[j]
            efficiency = fitness/material
            fitness_matrix[i][j] = fitness
            efficiency_matrix[i][j] = efficiency

            logging.info(f"morphology: {j}, rewardfunc: {i}, material cost: {material} reward: {reward} fitness: {fitness} efficiency: {efficiency}")

    best_efficiency = np.max(efficiency_matrix[:, 0])
    best_rewardfunc_index = np.argmax(efficiency_matrix[:, 0])
    logs_full = load_logs_full(f"results\Eureka\sac_morphology0_rewardfunc{best_rewardfunc_index}\SAC_{iter+1}")  
    epoch_freq = 500

    for tag, full_values in logs_full.items():
        sampled_values = full_values[::epoch_freq]
        max_val = max(sampled_values)
        mean_val = sum(sampled_values) / len(sampled_values)
        min_val = min(sampled_values)
        formatted_values = [f"{v:.2f}" for v in sampled_values]
        reward_reflection +=f"{tag}: {formatted_values}" + f"Max: {max_val:.2f}, Mean: {mean_val:.2f}, Min: {min_val:.2f}\n"

    best_message += f"best parameter:{best_rewardfunc} \n" + f"best fintess:{best_efficiency}" + eureka_rewardfunc_prompts.format(reward_reflection=reward_reflection)
# Out:
# Saved: results/eureka\env\GPTAnt_0_0.py
# 0 results/eureka\env\GPTAnt_0_0.py
# 0 results/eureka/assets/GPTAnt_0.xml
# Using cpu device
# Logging to results/eureka./sac_morphology0_rewardfunc0/SAC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2        |
# |    ep_rew_mean     | -2.05    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1033     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 32       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2        |
# |    ep_rew_mean     | -2.05    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 889      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 32       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.47     |
# |    ep_rew_mean     | -2.47    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 727      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 48       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41     |
# |    ep_rew_mean     | -2.36    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 770      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 64       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41     |
# |    ep_rew_mean     | -2.36    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 743      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 64       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.42     |
# |    ep_rew_mean     | -2.24    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 799      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 80       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41     |
# |    ep_rew_mean     | -2.06    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 833      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 96       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41     |
# |    ep_rew_mean     | -2.06    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 812      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 96       |
# ---------------------------------
# c:\Users\15482\anaconda3\envs\robodesign\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 3.44GB > 0.81GB
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49     |
# |    ep_rew_mean     | -2.07    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 635      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 112      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.49     |
# |    ep_rew_mean     | -2.07    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 623      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 112      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.45     |
# |    ep_rew_mean     | -2.08    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 658      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 128      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46     |
# |    ep_rew_mean     | -2.06    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 653      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 144      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46     |
# |    ep_rew_mean     | -2.06    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 641      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 144      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46     |
# |    ep_rew_mean     | -2.03    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 665      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 160      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5      |
# |    ep_rew_mean     | -2.03    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 690      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 176      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5      |
# |    ep_rew_mean     | -2.03    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 682      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 176      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5      |
# |    ep_rew_mean     | -2.05    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 708      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 192      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5      |
# |    ep_rew_mean     | -2.1     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 739      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 208      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5      |
# |    ep_rew_mean     | -2.1     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 731      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 208      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.52     |
# |    ep_rew_mean     | -2.09    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 765      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 224      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.53     |
# |    ep_rew_mean     | -2.07    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 787      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 240      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.53     |
# |    ep_rew_mean     | -2.07    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 777      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 240      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.53     |
# |    ep_rew_mean     | -2.01    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 800      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 256      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.53     |
# |    ep_rew_mean     | -2.01    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 794      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 256      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.59     |
# |    ep_rew_mean     | -1.98    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 843      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 288      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.59     |
# |    ep_rew_mean     | -1.98    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 831      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 288      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.59     |
# |    ep_rew_mean     | -1.98    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 823      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 288      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61     |
# |    ep_rew_mean     | -1.89    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 863      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 320      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61     |
# |    ep_rew_mean     | -1.89    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 856      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 320      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.61     |
# |    ep_rew_mean     | -1.89    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 849      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 320      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.62     |
# |    ep_rew_mean     | -1.92    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 865      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 336      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.6      |
# |    ep_rew_mean     | -1.87    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 877      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 352      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.63     |
# |    ep_rew_mean     | -1.92    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 888      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 368      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69     |
# |    ep_rew_mean     | -2.05    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 902      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 384      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69     |
# |    ep_rew_mean     | -2.05    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 895      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 384      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69     |
# |    ep_rew_mean     | -2.05    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 886      |
# |    time_elapsed    | 0        |
# |    total_timesteps |
|
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.83     |
# |    ep_rew_mean     | -2.18    |
# | time/              |          |
# |    episodes        | 4852     |
# |    fps             | 664      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19328    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.79     |
# |    ep_rew_mean     | -2.16    |
# | time/              |          |
# |    episodes        | 4856     |
# |    fps             | 660      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19344    |
# | train/             |          |
# |    actor_loss      | -9.95    |
# |    critic_loss     | 4.51     |
# |    ent_coef        | 0.917    |
# |    ent_coef_loss   | -1.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 292      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.84     |
# |    ep_rew_mean     | -2.21    |
# | time/              |          |
# |    episodes        | 4860     |
# |    fps             | 661      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19392    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.82     |
# |    ep_rew_mean     | -2.19    |
# | time/              |          |
# |    episodes        | 4864     |
# |    fps             | 661      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19408    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.82     |
# |    ep_rew_mean     | -2.15    |
# | time/              |          |
# |    episodes        | 4868     |
# |    fps             | 661      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19424    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.8      |
# |    ep_rew_mean     | -2.08    |
# | time/              |          |
# |    episodes        | 4872     |
# |    fps             | 662      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19456    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.75     |
# |    ep_rew_mean     | -2.11    |
# | time/              |          |
# |    episodes        | 4876     |
# |    fps             | 657      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19472    |
# | train/             |          |
# |    actor_loss      | -9.73    |
# |    critic_loss     | 4.68     |
# |    ent_coef        | 0.916    |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7      |
# |    ep_rew_mean     | -2.09    |
# | time/              |          |
# |    episodes        | 4880     |
# |    fps             | 658      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19504    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.71     |
# |    ep_rew_mean     | -2.05    |
# | time/              |          |
# |    episodes        | 4884     |
# |    fps             | 658      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19520    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7      |
# |    ep_rew_mean     | -2.07    |
# | time/              |          |
# |    episodes        | 4888     |
# |    fps             | 659      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19536    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69     |
# |    ep_rew_mean     | -2.01    |
# | time/              |          |
# |    episodes        | 4892     |
# |    fps             | 659      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19568    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.71     |
# |    ep_rew_mean     | -2.03    |
# | time/              |          |
# |    episodes        | 4896     |
# |    fps             | 656      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19600    |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 4.56     |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 300      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.71     |
# |    ep_rew_mean     | -1.98    |
# | time/              |          |
# |    episodes        | 4900     |
# |    fps             | 656      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19632    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.72     |
# |    ep_rew_mean     | -1.96    |
# | time/              |          |
# |    episodes        | 4904     |
# |    fps             | 657      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19648    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69     |
# |    ep_rew_mean     | -1.93    |
# | time/              |          |
# |    episodes        | 4908     |
# |    fps             | 657      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19680    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.68     |
# |    ep_rew_mean     | -1.89    |
# | time/              |          |
# |    episodes        | 4912     |
# |    fps             | 658      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 19712    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7      |
# |    ep_rew_mean     | -1.88    |
# | time/              |          |
# |    episodes        | 4916     |
# |    fps             | 653      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19728    |
# | train/             |          |
# |    actor_loss      | -9.98    |
# |    critic_loss     | 4.43     |
# |    ent_coef        | 0.913    |
# |    ent_coef_loss   | -1.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 304      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.68     |
# |    ep_rew_mean     | -1.87    |
# | time/              |          |
# |    episodes        | 4920     |
# |    fps             | 654      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19744    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.67     |
# |    ep_rew_mean     | -1.86    |
# | time/              |          |
# |    episodes        | 4924     |
# |    fps             | 654      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19776    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7      |
# |    ep_rew_mean     | -1.94    |
# | time/              |          |
# |    episodes        | 4928     |
# |    fps             | 655      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19792    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69     |
# |    ep_rew_mean     | -1.93    |
# | time/              |          |
# |    episodes        | 4932     |
# |    fps             | 655      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19824    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.69     |
# |    ep_rew_mean     | -1.91    |
# | time/              |          |
# |    episodes        | 4936     |
# |    fps             | 656      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19840    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.67     |
# |    ep_rew_mean     | -1.89    |
# | time/              |          |
# |    episodes        | 4940     |
# |    fps             | 652      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19856    |
# | train/             |          |
# |    actor_loss      | -9.93    |
# |    critic_loss     | 4.58     |
# |    ent_coef        | 0.912    |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 308      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.65     |
# |    ep_rew_mean     | -1.8     |
# | time/              |          |
# |    episodes        | 4944     |
# |    fps             | 653      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19888    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.64     |
# |    ep_rew_mean     | -1.8     |
# | time/              |          |
# |    episodes        | 4948     |
# |    fps             | 653      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19904    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.71     |
# |    ep_rew_mean     | -1.84    |
# | time/              |          |
# |    episodes        | 4952     |
# |    fps             | 654      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19952    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.73     |
# |    ep_rew_mean     | -1.88    |
# | time/              |          |
# |    episodes        | 4956     |
# |    fps             | 654      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 19968    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.71     |
# |    ep_rew_mean     | -1.91    |
# | time/              |          |
# |    episodes        | 4960     |
# |    fps             | 651      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 4.51     |
# |    ent_coef        | 0.911    |
# |    ent_coef_loss   | -1.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 312      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.67     |
# |    ep_rew_mean     | -1.89    |
# | time/              |          |
# |    episodes        | 4964     |
# |    fps             | 651      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 20016    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.7      |
# |    ep_rew_mean     | -1.94    |
# | time/              |          |
# |    episodes        | 4968     |
# |    fps             | 652      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 20048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.71     |
# |    ep_rew_mean     | -2.01    |
# | time/              |          |
# |    episodes        | 4972     |
# |    fps             | 652      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 20080    |
# ---------------------------------
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[41], line 24
#      22 env_name = "GPTAntEnv"
#      23 model_path = Train(j,  i, folder_name, total_timesteps=2e4, callback=True)
# ---> 24 fitness, reward = Eva(model_path)
#      26 material = material_list[j]
#      27 efficiency = fitness/material
#
# File c:\Users\15482\Desktop\Ant\utils.py:170, in Eva(model_path)
#     168 def Eva(model_path):
# --> 170     model = SAC.load(model_path)
#     171     current_dir = os.path.dirname(os.path.abspath(__file__))
#     172     xml_path = os.path.join(current_dir,"GPTAnt.xml")
#
# File c:\Users\15482\anaconda3\envs\robodesign\lib\site-packages\stable_baselines3\common\base_class.py:739, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     737 model.__dict__.update(data)
#     738 model.__dict__.update(kwargs)
# --> 739 model._setup_model()
#     741 try:
#     742     # put state_dicts back in place
#     743     model.set_parameters(params, exact_match=True, device=device)
#
# File c:\Users\15482\anaconda3\envs\robodesign\lib\site-packages\stable_baselines3\sac\sac.py:160, in SAC._setup_model(self)
#     159 def _setup_model(self) -> None:
# --> 160     super()._setup_model()
#     161     self._create_aliases()
#     162     # Running mean and running var
#
# File c:\Users\15482\anaconda3\envs\robodesign\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:189, in OffPolicyAlgorithm._setup_model(self)
#     187         assert self.env is not None, "You must pass an environment when using `HerReplayBuffer`"
#     188         replay_buffer_kwargs["env"] = self.env
# --> 189     self.replay_buffer = self.replay_buffer_class(
#     190         self.buffer_size,
#     191         self.observation_space,
#     192         self.action_space,
#     193         device=self.device,
#     194         n_envs=self.n_envs,
#     195         optimize_memory_usage=self.optimize_memory_usage,
#     196         **replay_buffer_kwargs,
#     197     )
#     199 self.policy = self.policy_class(
#     200     self.observation_space,
#     201     self.action_space,
#     202     self.lr_schedule,
#     203     **self.policy_kwargs,
#     204 )
#     205 self.policy = self.policy.to(self.device)
#
# File c:\Users\15482\anaconda3\envs\robodesign\lib\site-packages\stable_baselines3\common\buffers.py:216, in ReplayBuffer.__init__(self, buffer_size, observation_space, action_space, device, n_envs, optimize_memory_usage, handle_timeout_termination)
#     212 self.observations = np.zeros((self.buffer_size, self.n_envs, *self.obs_shape), dtype=observation_space.dtype)
#     214 if not optimize_memory_usage:
#     215     # When optimizing memory, `observations` contains also the next observation
# --> 216     self.next_observations = np.zeros((self.buffer_size, self.n_envs, *self.obs_shape), dtype=observation_space.dtype)
#     218 self.actions = np.zeros(
#     219     (self.buffer_size, self.n_envs, self.action_dim), dtype=self._maybe_cast_dtype(action_space.dtype)
#     220 )
#     222 self.rewards = np.zeros((self.buffer_size, self.n_envs), dtype=np.float32)
#
# MemoryError: Unable to allocate 1.56 GiB for an array with shape (125000, 16, 105) and data type float64

# %%
best_efficiency
# Out:
# 0.37703305549731986

# %%
reward_reflection = ''
logs_full = load_logs_full(f"results\Eureka\sac_morphology0_rewardfunc0\SAC_1")  
epoch_freq = 500

for tag, full_values in logs_full.items():
    sampled_values = full_values[::epoch_freq]
    max_val = max(sampled_values)
    mean_val = sum(sampled_values) / len(sampled_values)
    min_val = min(sampled_values)
    formatted_values = [f"{v:.2f}" for v in sampled_values]
    print(tag)
    reward_reflection +=f"{tag}: {formatted_values}, " + f"Max: {max_val:.2f}, Mean: {mean_val:.2f}, Min: {min_val:.2f}\n"

print(reward_reflection)
best_message += f"best parameter:{best_rewardfunc} \n" + f"best fintess:{best_efficiency}" + eureka_rewardfunc_prompts.format(reward_reflection=reward_reflection)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 reward_reflection = ''
# ----> 2 logs_full = load_logs_full(f"results\Eureka\sac_morphology0_rewardfunc0\SAC_1")
#       3 epoch_freq = 500
#       5 for tag, full_values in logs_full.items():
#
# Cell In[2], line 3, in load_logs_full(log_dir)
#       1 def load_logs_full(log_dir):
#       2     # 找到 .tfevents 文件
# ----> 3     event_file = [f for f in os.listdir(log_dir) if f.startswith("events.out")][0]
#       4     event_path = os.path.join(log_dir, event_file)
#       6     # 加载日志
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: 'results\\Eureka\\sac_morphology0_rewardfunc0\\SAC_1'
